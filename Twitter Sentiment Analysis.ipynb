# %% [raw]
# !pip install tweepy

# %% [raw]
# !pip install openpyxl

# %%
import numpy as np
import pandas as pd
import tweepy
import json
from tweepy import OAuthHandler

# %%
consumer_key = "LzsCOl12ZZ79FObx7BV9a1R3a"
consumer_secret = "gODxZ1kHJHDGgYfyP12AUN37UTlDd6yn3OsSV9Tl0iwu0K0cRY"
access_token = "296102538-kYIK8SULCmRK4vgvYD2DhKbwvSXrgTdTkWh0Nvsp"
access_token_secret = "Ib9obwgcE5tZk4S6tY5rAqI5iXOeJc9FGFg28qHoa4YpP"

# %%
auth = tweepy.OAuthHandler( consumer_key , consumer_secret )
auth.set_access_token( access_token , access_token_secret )
api = tweepy.API(auth)

# %%
query = "Covid Cases in India"

# %%
Tweets = api.search( query , count=10 , lang='en' , exclude='retweets' , tweet_mode='extended' )
# tweet_mode='extended'
# tweet_mode='compat'

for tweet in Tweets:
    print(tweet,"\n")
    print(".....................................\n")
# Out:
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 10:14:25 +0000 2021', 'id': 1359807999959736322, 'id_str': '1359807999959736322', 'full_text': 'The Newest Diplomatic Currency: Covid-19 Vaccines.  India, China, the U.A.E. and others dole out donations in countries where they seek sway. In some cases, they are sending doses despite pressing needs at home. https://t.co/NX0NZBgR9L #COVID19', 'truncated': False, 'display_text_range': [0, 244], 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [236, 244]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/NX0NZBgR9L', 'expanded_url': 'https://www.nytimes.com/2021/02/11/world/asia/vaccine-diplomacy-india-china.html?smid=tw-share', 'display_url': 'nytimes.com/2021/02/11/wor…', 'indices': [212, 235]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 256015042, 'id_str': '256015042', 'name': 'Steve Chao', 'screen_name': 'SteveChaoSC', 'location': 'Greater Asia', 'description': 'Emmy-nominated filmmaker, investigative journalist and TedX speaker. Unofficially known as Chao-KAPOW!', 'url': 'https://t.co/UcLKMbEssm', 'entities': {'url': {'urls': [{'url': 'https://t.co/UcLKMbEssm', 'expanded_url': 'http://about.me/chaosteve', 'display_url': 'about.me/chaosteve', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 10752, 'friends_count': 2102, 'listed_count': 389, 'created_at': 'Tue Feb 22 13:47:11 +0000 2011', 'favourites_count': 2350, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 18703, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '174F6B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256573036/ChaoPic2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256573036/ChaoPic2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/256015042/1398202792', 'profile_link_color': '184454', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 10, 14, 25), id=1359807999959736322, id_str='1359807999959736322', full_text='The Newest Diplomatic Currency: Covid-19 Vaccines.  India, China, the U.A.E. and others dole out donations in countries where they seek sway. In some cases, they are sending doses despite pressing needs at home. https://t.co/NX0NZBgR9L #COVID19', truncated=False, display_text_range=[0, 244], entities={'hashtags': [{'text': 'COVID19', 'indices': [236, 244]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/NX0NZBgR9L', 'expanded_url': 'https://www.nytimes.com/2021/02/11/world/asia/vaccine-diplomacy-india-china.html?smid=tw-share', 'display_url': 'nytimes.com/2021/02/11/wor…', 'indices': [212, 235]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_statu ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 10:07:28 +0000 2021', 'id': 1359806247801769988, 'id_str': '1359806247801769988', 'full_text': 'Kerala COVID: Kerala responsible for nearly half of all COVID cases in India: Where did it go wrong for the southern state? | India News  https://t.co/wyisiV4z58', 'truncated': False, 'display_text_range': [0, 161], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/wyisiV4z58', 'expanded_url': 'https://is.gd/ILYMZG', 'display_url': 'is.gd/ILYMZG', 'indices': [138, 161]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 206621610, 'id_str': '206621610', 'name': 'Unnikrishnan R Santhosh', 'screen_name': 'realunnikrish', 'location': 'Chennai, India', 'description': 'Journalist | Ex- @SunTV | @sunnewstamil | Researcher | |https://t.co/3wZEx8sq8I|  | Movie Tracker                     \n|RTs are not endorsements. | Views are personal |', 'url': 'https://t.co/mW3seLnQTo', 'entities': {'url': {'urls': [{'url': 'https://t.co/mW3seLnQTo', 'expanded_url': 'https://www.facebook.com/unni.krishnan.9484', 'display_url': 'facebook.com/unni.krishnan.…', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/3wZEx8sq8I', 'expanded_url': 'http://Thuglak.com', 'display_url': 'Thuglak.com', 'indices': [56, 79]}]}}, 'protected': False, 'followers_count': 3386, 'friends_count': 2509, 'listed_count': 1, 'created_at': 'Sat Oct 23 10:39:55 +0000 2010', 'favourites_count': 7666, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 11150, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1300463559185326081/rpuJHswX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1300463559185326081/rpuJHswX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/206621610/1596798597', 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 10, 7, 28), id=1359806247801769988, id_str='1359806247801769988', full_text='Kerala COVID: Kerala responsible for nearly half of all COVID cases in India: Where did it go wrong for the southern state? | India News  https://t.co/wyisiV4z58', truncated=False, display_text_range=[0, 161], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/wyisiV4z58', 'expanded_url': 'https://is.gd/ILYMZG', 'display_url': 'is.gd/ILYMZG', 'indices': [138, 161]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000 ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 10:07:02 +0000 2021', 'id': 1359806141140619268, 'id_str': '1359806141140619268', 'full_text': 'On February 10, Mumbai recorded 558 new Covid-19 cases and the count of active cases rose to 5,369. | @pankajcreates\n#Mumbai #Coronavirus #Covid19\nhttps://t.co/N6Xr2BS4SM', 'truncated': False, 'display_text_range': [0, 170], 'entities': {'hashtags': [{'text': 'Mumbai', 'indices': [117, 124]}, {'text': 'Coronavirus', 'indices': [125, 137]}, {'text': 'Covid19', 'indices': [138, 146]}], 'symbols': [], 'user_mentions': [{'screen_name': 'pankajcreates', 'name': 'Pankaj Upadhyay', 'id': 492305681, 'id_str': '492305681', 'indices': [102, 116]}], 'urls': [{'url': 'https://t.co/N6Xr2BS4SM', 'expanded_url': 'https://www.indiatoday.in/india/story/mumbai-sudden-spike-in-coronavirus-cases-reported-after-resumption-of-local-trains-1768223-2021-02-11', 'display_url': 'indiatoday.in/india/story/mu…', 'indices': [147, 170]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19897138, 'id_str': '19897138', 'name': 'IndiaToday', 'screen_name': 'IndiaToday', 'location': 'India', 'description': 'Brings you news breaks: Exclusive political, entertainment, sports insight, unbiased-nonaligned. We are also on Instagram : https://t.co/qf1v42FMpb', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/qf1v42FMpb', 'expanded_url': 'https://www.instagram.com/indiatoday', 'display_url': 'instagram.com/indiatoday', 'indices': [124, 147]}]}}, 'protected': False, 'followers_count': 5490501, 'friends_count': 251, 'listed_count': 5749, 'created_at': 'Mon Feb 02 07:21:54 +0000 2009', 'favourites_count': 4439, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 832357, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1323664537770323968/vD4Ifa_b_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1323664537770323968/vD4Ifa_b_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19897138/1612943701', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 10, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 10, 7, 2), id=1359806141140619268, id_str='1359806141140619268', full_text='On February 10, Mumbai recorded 558 new Covid-19 cases and the count of active cases rose to 5,369. | @pankajcreates\n#Mumbai #Coronavirus #Covid19\nhttps://t.co/N6Xr2BS4SM', truncated=False, display_text_range=[0, 170], entities={'hashtags': [{'text': 'Mumbai', 'indices': [117, 124]}, {'text': 'Coronavirus', 'indices': [125, 137]}, {'text': 'Covid19', 'indices': [138, 146]}], 'symbols': [], 'user_mentions': [{'screen_name': 'pankajcreates', 'name': 'Pankaj Upadhyay', 'id': 492305681, 'id_str': '492305681', 'indices': [102, 116]}], 'urls' ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 10:05:00 +0000 2021', 'id': 1359805627841847296, 'id_str': '1359805627841847296', 'full_text': 'UPDATE | Russia registers 15,038 COVID-19 cases in past 24 hours\n\n#SputnikUpdates https://t.co/QjWxK28UoQ', 'truncated': False, 'display_text_range': [0, 105], 'entities': {'hashtags': [{'text': 'SputnikUpdates', 'indices': [66, 81]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QjWxK28UoQ', 'expanded_url': 'http://sptnkne.ws/FrTa', 'display_url': 'sptnkne.ws/FrTa', 'indices': [82, 105]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': 1359800594328920070, 'in_reply_to_status_id_str': '1359800594328920070', 'in_reply_to_user_id': 34262462, 'in_reply_to_user_id_str': '34262462', 'in_reply_to_screen_name': 'SputnikInt', 'user': {'id': 34262462, 'id_str': '34262462', 'name': 'Sputnik', 'screen_name': 'SputnikInt', 'location': '', 'description': 'Sputnik is a global wire, radio and digital news service. We exist to tell the stories that aren’t being told.', 'url': 'https://t.co/CGNEJoSLHS', 'entities': {'url': {'urls': [{'url': 'https://t.co/CGNEJoSLHS', 'expanded_url': 'http://sputniknews.com', 'display_url': 'sputniknews.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 322967, 'friends_count': 302, 'listed_count': 6570, 'created_at': 'Wed Apr 22 12:55:28 +0000 2009', 'favourites_count': 24, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 149871, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1338442439862996992/LABf4E_j_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1338442439862996992/LABf4E_j_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34262462/1609664134', 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '056EAB', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 10, 5), id=1359805627841847296, id_str='1359805627841847296', full_text='UPDATE | Russia registers 15,038 COVID-19 cases in past 24 hours\n\n#SputnikUpdates https://t.co/QjWxK28UoQ', truncated=False, display_text_range=[0, 105], entities={'hashtags': [{'text': 'SputnikUpdates', 'indices': [66, 81]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QjWxK28UoQ', 'expanded_url': 'http://sptnkne.ws/FrTa', 'display_url': 'sptnkne.ws/FrTa', 'indices': [82, 105]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='TweetDeck', source_url='https://about.twitter.com/products/tweetdeck', in_reply_to_status_id=1359800594328920070, in_reply_to_status_id_str='1359800594328920070', in_reply_to_user_id=34262462, in_reply_to_user_id_str='34262462', in_reply_to_screen_name='SputnikInt', author=User(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'id': 34262462, 'id_str': '34262462', 'name': 'Sputnik', 'screen_name': 'SputnikInt', 'location': '', 'descript ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 10:00:01 +0000 2021', 'id': 1359804373568811014, 'id_str': '1359804373568811014', 'full_text': 'COVID 19 cases in India until : 11/02/2021 15:30\n\nTotal Cases: 10871301 [+241]😅\nActive: 139562🖖🏽\nRecovered: 10571749 [+120]❤\nDeaths :155399 [+0]🙏🏼\nTotal Tests: 204.02M🧪\n\nData- @covid19indiaorg\n#CoronaVirus #COVID19inIndia #India #Bot', 'truncated': False, 'display_text_range': [0, 233], 'entities': {'hashtags': [{'text': 'CoronaVirus', 'indices': [193, 205]}, {'text': 'COVID19inIndia', 'indices': [206, 221]}, {'text': 'India', 'indices': [222, 228]}, {'text': 'Bot', 'indices': [229, 233]}], 'symbols': [], 'user_mentions': [{'screen_name': 'covid19indiaorg', 'name': 'covid19indiaorg', 'id': 1240561169296814080, 'id_str': '1240561169296814080', 'indices': [176, 192]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://indiacovid19bot.azurewebsites.net/" rel="nofollow">BharatCovid19Bot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1254115932021993472, 'id_str': '1254115932021993472', 'name': 'Coronavirus Bot 🇮🇳', 'screen_name': 'IndiaCovid19Bot', 'location': '', 'description': "A bot HOURLY posting India's Covid 19 numbers.\nRuns from 9am to 11 30pm IST. \nMade by \n@SamitShirsat", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 112, 'friends_count': 2, 'listed_count': 2, 'created_at': 'Sat Apr 25 18:32:00 +0000 2020', 'favourites_count': 8, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4308, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1254353902364852224/UKUj3u4l_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254353902364852224/UKUj3u4l_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254115932021993472/1587896661', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 10, 0, 1), id=1359804373568811014, id_str='1359804373568811014', full_text='COVID 19 cases in India until : 11/02/2021 15:30\n\nTotal Cases: 10871301 [+241]😅\nActive: 139562🖖🏽\nRecovered: 10571749 [+120]❤\nDeaths :155399 [+0]🙏🏼\nTotal Tests: 204.02M🧪\n\nData- @covid19indiaorg\n#CoronaVirus #COVID19inIndia #India #Bot', truncated=False, display_text_range=[0, 233], entities={'hashtags': [{'text': 'CoronaVirus', 'indices': [193, 205]}, {'text': 'COVID19inIndia', 'indices': [206, 221]}, {'text': 'India', 'indices': [222, 228]}, {'text': 'Bot', 'indices': [229, 233]}], 'symbols': [], 'user_mentions': [{'screen_name': 'covid19indiaorg', 'name': 'covid19indiaorg', 'id': 1240561169296814080, 'id_str': '1240561169296814080', 'indices': [176, 192]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='BharatCovid19Bot', source_url='https://indiacovid19bot.azurewebsites.net/', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_rep ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 09:57:35 +0000 2021', 'id': 1359803764178255874, 'id_str': '1359803764178255874', 'full_text': 'Scientists say every third or fourth person in the country is harboring antibodies against the SARS-CoV2 virus. This could probably explain why #COVID19 cases have been coming down gradually in the country.\n-@gyanc7, Genetics Prof., BHU\n#WeStandWithIndia✊\nhttps://t.co/zNYhlGUP04', 'truncated': False, 'display_text_range': [0, 279], 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [144, 152]}, {'text': 'WeStandWithIndia', 'indices': [237, 254]}], 'symbols': [], 'user_mentions': [{'screen_name': 'gyanc7', 'name': 'Gyaneshwer Chaubey', 'id': 111314182, 'id_str': '111314182', 'indices': [208, 215]}], 'urls': [{'url': 'https://t.co/zNYhlGUP04', 'expanded_url': 'http://bit.ly/3jGMG2a', 'display_url': 'bit.ly/3jGMG2a', 'indices': [256, 279]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1960063177, 'id_str': '1960063177', 'name': 'NATHEALTH #WeStandWithIndia✊', 'screen_name': 'nathealthindia', 'location': 'India', 'description': 'Healthcare Federation of India', 'url': 'http://t.co/roOoZMZzDl', 'entities': {'url': {'urls': [{'url': 'http://t.co/roOoZMZzDl', 'expanded_url': 'http://www.nathealthindia.org', 'display_url': 'nathealthindia.org', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 966, 'friends_count': 354, 'listed_count': 59, 'created_at': 'Mon Oct 14 06:08:50 +0000 2013', 'favourites_count': 1769, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4134, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1070996023127040000/JyxxQLZN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1070996023127040000/JyxxQLZN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1960063177/1611315081', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 9, 57, 35), id=1359803764178255874, id_str='1359803764178255874', full_text='Scientists say every third or fourth person in the country is harboring antibodies against the SARS-CoV2 virus. This could probably explain why #COVID19 cases have been coming down gradually in the country.\n-@gyanc7, Genetics Prof., BHU\n#WeStandWithIndia✊\nhttps://t.co/zNYhlGUP04', truncated=False, display_text_range=[0, 279], entities={'hashtags': [{'text': 'COVID19', 'indices': [144, 152]}, {'text': 'WeStandWithIndia', 'indices': [237, 254]}], 'symbols': [], 'user_mentions': [{'screen_name': 'gyanc7', 'name': 'Gyaneshwer Chaubey', 'id': 111314182, 'id_str': '111314182', 'indices': [208, 215]}], 'urls': [{'url': 'https://t.co/zNYhlGUP04', 'expanded_url': 'http://bit.ly/3jGMG2a', ' ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 09:32:00 +0000 2021', 'id': 1359797322985721858, 'id_str': '1359797322985721858', 'full_text': "India's COVID-19 tally has climbed to 1,08,71,294 with 12,923 fresh cases reported in a day, while the number of recoveries has surged to 1,05,73,372, the health ministry said on Thursday.\nhttps://t.co/EwUjdorX9z", 'truncated': False, 'display_text_range': [0, 212], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/EwUjdorX9z', 'expanded_url': 'https://www.telegraphindia.com/india/india-logs-more-than-12000-fresh-covid-cases-108-casualties-in-a-day/cid/1806353?utm_source=twitter&utm_medium=social&utm_campaign=tt_daily_twit', 'display_url': 'telegraphindia.com/india/india-lo…', 'indices': [189, 212]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 141080858, 'id_str': '141080858', 'name': 'The Telegraph', 'screen_name': 'ttindia', 'location': 'Kolkata, India', 'description': 'The unputdownable English newspaper of the ABP group published from Calcutta, India. Retweets are not endorsements.', 'url': 'https://t.co/bfJK3Hc3fH', 'entities': {'url': {'urls': [{'url': 'https://t.co/bfJK3Hc3fH', 'expanded_url': 'https://www.telegraphindia.com', 'display_url': 'telegraphindia.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 241308, 'friends_count': 77, 'listed_count': 891, 'created_at': 'Fri May 07 04:10:03 +0000 2010', 'favourites_count': 202, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 53936, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1277634913701785600/w7H4CCF4_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277634913701785600/w7H4CCF4_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/141080858/1593446877', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 5, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 9, 32), id=1359797322985721858, id_str='1359797322985721858', full_text="India's COVID-19 tally has climbed to 1,08,71,294 with 12,923 fresh cases reported in a day, while the number of recoveries has surged to 1,05,73,372, the health ministry said on Thursday.\nhttps://t.co/EwUjdorX9z", truncated=False, display_text_range=[0, 212], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/EwUjdorX9z', 'expanded_url': 'https://www.telegraphindia.com/india/india-logs-more-than-12000-fresh-covid-cases-108-casualties-in-a-day/cid/1806353?utm_source=twitter&utm_medium=social&utm_campaign=tt_daily_twit', 'display_url': 'telegraphindia.com/india/india-lo…', 'indices': [189, 212]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitt ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 09:30:00 +0000 2021', 'id': 1359796819463667719, 'id_str': '1359796819463667719', 'full_text': 'Kerala responsible for nearly half of all COVID cases in India: Where did it go wrong for the southern state.\n\nhttps://t.co/Et31vtMjqD', 'truncated': False, 'display_text_range': [0, 134], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Et31vtMjqD', 'expanded_url': 'https://www.timesnownews.com/india/article/kerala-responsible-for-nearly-half-of-all-covid-cases-in-india-where-did-it-go-wrong-for-the-southern-state/718869', 'display_url': 'timesnownews.com/india/article/…', 'indices': [111, 134]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 240649814, 'id_str': '240649814', 'name': 'TIMES NOW', 'screen_name': 'TimesNow', 'location': 'India', 'description': 'TIMES NOW is India’s most watched English news channel. Follow for lightning fast #BreakingNews and #Alerts.', 'url': 'https://t.co/1r9xZjg7do', 'entities': {'url': {'urls': [{'url': 'https://t.co/1r9xZjg7do', 'expanded_url': 'http://www.timesnownews.com', 'display_url': 'timesnownews.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 9949142, 'friends_count': 373, 'listed_count': 5193, 'created_at': 'Thu Jan 20 12:17:23 +0000 2011', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 622542, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1354074536925388802/qkHhpnVw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1354074536925388802/qkHhpnVw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240649814/1612255794', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 13, 'favorite_count': 69, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 9, 30), id=1359796819463667719, id_str='1359796819463667719', full_text='Kerala responsible for nearly half of all COVID cases in India: Where did it go wrong for the southern state.\n\nhttps://t.co/Et31vtMjqD', truncated=False, display_text_range=[0, 134], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Et31vtMjqD', 'expanded_url': 'https://www.timesnownews.com/india/article/kerala-responsible-for-nearly-half-of-all-covid-cases-in-india-where-did-it-go-wrong-for-the-southern-state/718869', 'display_url': 'timesnownews.com/india/article/…', 'indices': [111, 134]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='TweetDeck', source_url='https://about.twitter.com/products/tweetdeck', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 09:28:24 +0000 2021', 'id': 1359796418127405056, 'id_str': '1359796418127405056', 'full_text': 'Covid-19: India records 12,923 fresh cases, 108 more fatalities https://t.co/Rx1Qq8XV1V via @timesofindia', 'truncated': False, 'display_text_range': [0, 105], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'timesofindia', 'name': 'The Times Of India', 'id': 134758540, 'id_str': '134758540', 'indices': [92, 105]}], 'urls': [{'url': 'https://t.co/Rx1Qq8XV1V', 'expanded_url': 'http://toi.in/Lt0Xwa/a24gj', 'display_url': 'toi.in/Lt0Xwa/a24gj', 'indices': [64, 87]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1297543645776605185, 'id_str': '1297543645776605185', 'name': 'HARSH VARDHAN SINGH❄🌛CODE RED🔥LORD OF THE GHOSTS', 'screen_name': 'NUCLEARCRISIS19', 'location': 'ROHTAK - HARYANA  - INDIA ', 'description': 'DEATHWAVE MOONCHILD SON BROTHER FRIEND ☢☣✝️  ☢ ORDINARY GUY☢RAJPUT-JAT ALWAYS INJURED☢ DAYDREAMER☣NIGHTOWL ☣RAINLOVER ☢FAN☣ COBRA ☣ 🌿STRAIGHT💪TIGER LION 🐅🌞', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 22, 'friends_count': 635, 'listed_count': 1, 'created_at': 'Sun Aug 23 14:38:34 +0000 2020', 'favourites_count': 561, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 9590, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1356122186918948868/uzL0jt86_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1356122186918948868/uzL0jt86_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1297543645776605185/1609227762', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 9, 28, 24), id=1359796418127405056, id_str='1359796418127405056', full_text='Covid-19: India records 12,923 fresh cases, 108 more fatalities https://t.co/Rx1Qq8XV1V via @timesofindia', truncated=False, display_text_range=[0, 105], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'timesofindia', 'name': 'The Times Of India', 'id': 134758540, 'id_str': '134758540', 'indices': [92, 105]}], 'urls': [{'url': 'https://t.co/Rx1Qq8XV1V', 'expanded_url': 'http://toi.in/Lt0Xwa/a24gj', 'display_url': 'toi.in/Lt0Xwa/a24gj', 'indices': [64, 87]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'id': 1297543645776605185, 'id_str': '1297543645776605185', 'name': 'HARSH VARDHAN SINGH❄🌛CODE RED🔥LORD OF THE GHOSTS', 'screen_name': 'NUCLEARCRISIS19', 'location': 'RO ...
#
# .....................................
#
# Status(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'created_at': 'Thu Feb 11 09:21:54 +0000 2021', 'id': 1359794781363138563, 'id_str': '1359794781363138563', 'full_text': 'We are repeating the same mistake with genome surveillance which we did with testing that is not utilising our capacities.\nINSACOG today has capacity of sequencing 45000 thousand samples per month.\nIn last one month India reported 3,70,000 new covid cases. While we claim\n\n(1/n)', 'truncated': False, 'display_text_range': [0, 278], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 172305350, 'id_str': '172305350', 'name': 'Maneesh', 'screen_name': 'Maneesh312', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1386, 'friends_count': 870, 'listed_count': 6, 'created_at': 'Thu Jul 29 11:28:35 +0000 2010', 'favourites_count': 1544, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2641, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/967480119555010560/FzI37v8o_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967480119555010560/FzI37v8o_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/172305350/1490740502', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 11, 9, 21, 54), id=1359794781363138563, id_str='1359794781363138563', full_text='We are repeating the same mistake with genome surveillance which we did with testing that is not utilising our capacities.\nINSACOG today has capacity of sequencing 45000 thousand samples per month.\nIn last one month India reported 3,70,000 new covid cases. While we claim\n\n(1/n)', truncated=False, display_text_range=[0, 278], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026ED3F2FE88>, _json={'id': 172305350, 'id_str': '172305350', 'name': 'Maneesh', 'screen_name': 'Maneesh312', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1386, 'friends_count': 870, 'listed_count': 6, 'created_at': 'Thu Jul 29 11:28:35 +0000 2010', 'favourites_count': 1544, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2641, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enable ...
#
# .....................................

# %% [raw]
# Getting the tweets and some Attributes

# %%
df = pd.DataFrame(columns = ['Tweets' , 'User' , 'User_statuses_count' , 
                            'user_followers' , 'User_location' , 'User_verified' ,
                            'fav_count' , 'rt_count' , 'tweet_date'] )
print(df)
print(df.shape)
# Out:
# Empty DataFrame
# Columns: [Tweets, User, User_statuses_count, user_followers, User_location, User_verified, fav_count, rt_count, tweet_date]
# Index: []
# (0, 9)

# %%
def stream(data, file_name):
    i = 0
    for tweet in tweepy.Cursor(api.search, q=data, count=100, lang='en').items():
        print(i, end='\r')
        df.loc[i, 'Tweets'] = tweet.text
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count
        df.loc[i, 'user_followers'] = tweet.user.followers_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'User_verified'] = tweet.user.verified
        df.loc[i, 'fav_count'] = tweet.favorite_count
        df.loc[i, 'rt_count'] = tweet.retweet_count
        df.loc[i, 'tweet_date'] = tweet.created_at
        df.to_excel('{}.xlsx'.format(file_name))
        i = i+1
        if i == 1000:
            break
        else:
            pass

# %%
stream(data=["Covid cases in India"] , file_name='my_tweets')
# Out:
# 999

# %%
df.head(999)
# Out:
#                                                 Tweets  \
# 0    COVID 19 cases in India until : 11/02/2021 13:...
# 1    RT @SputnikInt: MORE | WHO not ruling out COVI...
# 2    #CornavirusUpdates \n\n🔷️ India becomes fastes...
# 3    #CoronaVirusUpdates | India active cases at 14...
# 4    RT @IndiaSpend: From a success story hailed ac...
# ..                                                 ...
# 994  RT @thakkar_sameet: Covid cases in double digi...
# 995  RT @COVIDNewsByMIB: #CoronaVirusUpdates: \n\n📍...
# 996  Why Did COVID-19 Cases Dramatically Decline In...
# 997  RT @thakkar_sameet: Covid cases in double digi...
# 998  RT @thakkar_sameet: Covid cases in double digi...
#
#                                User User_statuses_count user_followers  \
# 0                Coronavirus Bot 🇮🇳                4306            112
# 1    IlNuovoMondo Patriota Digitale                2612            104
# 2                 Siddhantha Sharma                 777             23
# 3                 Business Standard              325408        2063391
# 4                        BitterPill               22751            457
# ..                              ...                 ...            ...
# 994                        A D Shah              114967            562
# 995                Daulat Ram Sihag               17268             33
# 996                 Christine Plumb                   5              8
# 997                        abhishek               19336            155
# 998                              SS               35892            283
#
#                       User_location User_verified fav_count rt_count  \
# 0                                           False         0        0
# 1    Scheveningen Badplaats, Den Ha         False         0        2
# 2                                           False         0        0
# 3                             India          True         2        1
# 4                     Bhopal, India         False         0        2
# ..                              ...           ...       ...      ...
# 994                    Bharatvarsha         False         0      625
# 995                                         False         0       44
# 996                                         False         1        0
# 997                                         False         0      625
# 998   Amberpet Extention, Hyderabad         False         0      625
#
#               tweet_date
# 0    2021-02-11 08:00:00
# 1    2021-02-11 07:59:42
# 2    2021-02-11 07:56:00
# 3    2021-02-11 07:50:21
# 4    2021-02-11 07:50:17
# ..                   ...
# 994  2021-02-10 01:05:48
# 995  2021-02-10 01:03:57
# 996  2021-02-10 01:03:48
# 997  2021-02-10 00:58:33
# 998  2021-02-10 00:58:07
#
# [999 rows x 9 columns]

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\katis\anaconda3\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in c:\users\katis\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.14.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %% [raw]
# Sentiment(polarity, subjectivity)
#
# Polarity score: [-1 , +1]
#
# Subjectivity: [0.0 , 1.0]
# where 0.0 is very Objective and 1.0 is very Subjective.

# %%
from textblob import TextBlob

# %%
import re
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# %%
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['clean_tweet'] = df['Tweets'].apply(lambda x : clean_tweet(x))

# %%
df.head(999)
# Out:
#                                                 Tweets  \
# 0    COVID 19 cases in India until : 11/02/2021 13:...
# 1    RT @SputnikInt: MORE | WHO not ruling out COVI...
# 2    #CornavirusUpdates \n\n🔷️ India becomes fastes...
# 3    #CoronaVirusUpdates | India active cases at 14...
# 4    RT @IndiaSpend: From a success story hailed ac...
# ..                                                 ...
# 994  RT @thakkar_sameet: Covid cases in double digi...
# 995  RT @COVIDNewsByMIB: #CoronaVirusUpdates: \n\n📍...
# 996  Why Did COVID-19 Cases Dramatically Decline In...
# 997  RT @thakkar_sameet: Covid cases in double digi...
# 998  RT @thakkar_sameet: Covid cases in double digi...
#
#                                User User_statuses_count user_followers  \
# 0                Coronavirus Bot 🇮🇳                4306            112
# 1    IlNuovoMondo Patriota Digitale                2612            104
# 2                 Siddhantha Sharma                 777             23
# 3                 Business Standard              325408        2063391
# 4                        BitterPill               22751            457
# ..                              ...                 ...            ...
# 994                        A D Shah              114967            562
# 995                Daulat Ram Sihag               17268             33
# 996                 Christine Plumb                   5              8
# 997                        abhishek               19336            155
# 998                              SS               35892            283
#
#                       User_location User_verified fav_count rt_count  \
# 0                                           False         0        0
# 1    Scheveningen Badplaats, Den Ha         False         0        2
# 2                                           False         0        0
# 3                             India          True         2        1
# 4                     Bhopal, India         False         0        2
# ..                              ...           ...       ...      ...
# 994                    Bharatvarsha         False         0      625
# 995                                         False         0       44
# 996                                         False         1        0
# 997                                         False         0      625
# 998   Amberpet Extention, Hyderabad         False         0      625
#
#               tweet_date                                        clean_tweet
# 0    2021-02-11 08:00:00  COVID 19 cases in India until 11 02 2021 13 30...
# 1    2021-02-11 07:59:42  RT MORE WHO not ruling out COVID 19 already ci...
# 2    2021-02-11 07:56:00  CornavirusUpdates India becomes fastest in the...
# 3    2021-02-11 07:50:21  CoronaVirusUpdates India active cases at 142 5...
# 4    2021-02-11 07:50:17  RT From a success story hailed across the worl...
# ..                   ...                                                ...
# 994  2021-02-10 01:05:48  RT sameet Covid cases in double digits amp no ...
# 995  2021-02-10 01:03:57  RT CoronaVirusUpdates Total COVID19 Cases in I...
# 996  2021-02-10 01:03:48  Why Did COVID 19 Cases Dramatically Decline In...
# 997  2021-02-10 00:58:33  RT sameet Covid cases in double digits amp no ...
# 998  2021-02-10 00:58:07  RT sameet Covid cases in double digits amp no ...
#
# [999 rows x 10 columns]

# %%
df['Sentiment'] = df['clean_tweet'].apply(lambda x : analyze_sentiment(x) )
df.head(99)
# Out:
#                                                Tweets  \
# 0   COVID 19 cases in India until : 11/02/2021 13:...
# 1   RT @SputnikInt: MORE | WHO not ruling out COVI...
# 2   #CornavirusUpdates \n\n🔷️ India becomes fastes...
# 3   #CoronaVirusUpdates | India active cases at 14...
# 4   RT @IndiaSpend: From a success story hailed ac...
# ..                                                ...
# 94  India's Covid-19 tally has climbed to 1,08,71,...
# 95  RT @ani_digital: India registers over 12,000 n...
# 96  RT @drkaalika: With 8,635 Covid-19 cases, Indi...
# 97  RT @COVIDNewsByMIB: #CoronaVirusUpdates: \n\n📍...
# 98  RT @COVIDNewsByMIB: #CoronaVirusUpdates: \n\n📍...
#
#                                                  User User_statuses_count  \
# 0                                  Coronavirus Bot 🇮🇳                4306
# 1                      IlNuovoMondo Patriota Digitale                2612
# 2                                   Siddhantha Sharma                 777
# 3                                   Business Standard              325408
# 4                                          BitterPill               22751
# ..                                                ...                 ...
# 94                                      Business Line              249907
# 95                                       TANMOY BOURI               29450
# 96                                 MOHAMMAD TASLIM 🇮🇳                9627
# 97                                      Yoga Ayurveda              108974
# 98  FieldOutreachBureau,Balasore(Odisha)#mask😷urself#                2447
#
#    user_followers                   User_location User_verified fav_count  \
# 0             112                                         False         0
# 1             104  Scheveningen Badplaats, Den Ha         False         0
# 2              23                                         False         0
# 3         2063391                           India          True         2
# 4             457                   Bhopal, India         False         0
# ..            ...                             ...           ...       ...
# 94          75135                  Chennai, India          True         0
# 95            266                                         False         0
# 96            774                  Kolkata, India         False         0
# 97            572                  Kolkata, India         False         0
# 98            162                       Balasore          False         0
#
#    rt_count           tweet_date  \
# 0         0  2021-02-11 08:00:00
# 1         2  2021-02-11 07:59:42
# 2         0  2021-02-11 07:56:00
# 3         1  2021-02-11 07:50:21
# 4         2  2021-02-11 07:50:17
# ..      ...                  ...
# 94        0  2021-02-11 05:20:32
# 95        2  2021-02-11 05:20:16
# 96       12  2021-02-11 05:19:58
# 97       30  2021-02-11 05:18:59
# 98       30  2021-02-11 05:18:01
#
#                                           clean_tweet Sentiment
# 0   COVID 19 cases in India until 11 02 2021 13 30...  Negative
# 1   RT MORE WHO not ruling out COVID 19 already ci...  Positive
# 2   CornavirusUpdates India becomes fastest in the...   Neutral
# 3   CoronaVirusUpdates India active cases at 142 5...  Positive
# 4   RT From a success story hailed across the worl...  Positive
# ..                                                ...       ...
# 94  India s Covid 19 tally has climbed to 1 08 71 ...  Positive
# 95  RT digital India registers over 12 000 new COV...  Positive
# 96  RT With 8 635 Covid 19 cases India records low...  Negative
# 97  RT CoronaVirusUpdates Total COVID19 Cases in I...   Neutral
# 98  RT CoronaVirusUpdates Total COVID19 Cases in I...   Neutral
#
# [99 rows x 11 columns]

# %%
n = 20
print("Original tweet:\n",df['Tweets'][n])
print()
print("Clean tweet:\n",df['clean_tweet'][n])
print()
print("Sentiment of the tweet:\n",df['Sentiment'][n])
# Out:
# Original tweet:
#  Times of India: 2,515 new Covid-19 cases in Maharashtra, 35 deaths.
# https://t.co/agzIyCm4Lt
#
# via @GoogleNews
#
# Clean tweet:
#  Times of India 2 515 new Covid 19 cases in Maharashtra 35 deaths via
#
# Sentiment of the tweet:
#  Positive

# %%
n = 200
print("Original tweet:\n",df['Tweets'][n])
print()
print("Clean tweet:\n",df['clean_tweet'][n])
print()
print("Sentiment of the tweet:\n",df['Sentiment'][n])
# Out:
# Original tweet:
#  RT @RohanRavi18: @DrRPNishank @cbseindia29 @SanjayDhotreMP @EduMinOfIndia @PIB_India Sir In India Are COVID cases have reached 0 ? Or there…
#
# Clean tweet:
#  RT India Sir In India Are COVID cases have reached 0 Or there
#
# Sentiment of the tweet:
#  Neutral

# %%
n = 203
print("Original tweet:\n",df['Tweets'][n])
print()
print("Clean tweet:\n",df['clean_tweet'][n])
print()
print("Sentiment of the tweet:\n",df['Sentiment'][n])
# Out:
# Original tweet:
#  RT @chennithala: Today Kerala is the leading state in India on Covid cases. The inefficiency of this LDF Govt has bought us to this tragic…
#
# Clean tweet:
#  RT Today Kerala is the leading state in India on Covid cases The inefficiency of this LDF Govt has bought us to this tragic
#
# Sentiment of the tweet:
#  Negative

# %%
df[df.Sentiment == 'Positive'].shape[0]
# Out:
# 557

# %%
df[df.Sentiment == 'Neutral'].shape[0]
# Out:
# 234

# %%
df[df.Sentiment == 'Negative'].shape[0]
# Out:
# 209
